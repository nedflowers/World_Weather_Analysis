# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAlFCnut-bJJNZerRtvbk54EHwI4QhRTOR4FOI-KJfnBC14kUMurBr-PVaEkydC6OXafym6NCi1_B5iq5HmNUeM9ya224ePKJjPjQbEOjGRuoThcV4mcgLkJzLdLcMkDaWKaySXsCvsgt1ZbYMhSjw2OjeMne4pZOi1rEE-jQqh9fyFSUDCc78d8jml6poBPQaNieEYGyFRLcYERyROFv2VAi_W4vR-T5NEBg_P_eyN2IlRUjn83PMBQOBj7CL28W5CURV_iwGmtovA3q9iUq2669Mt3OZ2PsMtD765-d3NRmQPnOutpT6PKoBhQLtB981V6ut_l3T-pAwltguAxiMhk3z0j-40Suxt_WZW3h_MrcQf4MNqpko3-g3oQl50Iop2H9IiK0clKUzXqCSu2xvnI5cLEaoic_9T_o7llUO7OG2EeJE9emox',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
# View next page

page2_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=Aap_uEAlFCnut-bJJNZerRtvbk54EHwI4QhRTOR4FOI-KJfnBC14kUMurBr-PVaEkydC6OXafym6NCi1_B5iq5HmNUeM9ya224ePKJjPjQbEOjGRuoThcV4mcgLkJzLdLcMkDaWKaySXsCvsgt1ZbYMhSjw2OjeMne4pZOi1rEE-jQqh9fyFSUDCc78d8jml6poBPQaNieEYGyFRLcYERyROFv2VAi_W4vR-T5NEBg_P_eyN2IlRUjn83PMBQOBj7CL28W5CURV_iwGmtovA3q9iUq2669Mt3OZ2PsMtD765-d3NRmQPnOutpT6PKoBhQLtB981V6ut_l3T-pAwltguAxiMhk3z0j-40Suxt_WZW3h_MrcQf4MNqpko3-g3oQl50Iop2H9IiK0clKUzXqCSu2xvnI5cLEaoic_9T_o7llUO7OG2EeJE9emox=g_key"

hotels2 = requests.get(page2_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAlFCnut-bJJNZerRtvbk54EHwI4QhRTOR4FOI-KJfnBC14kUMurBr-PVaEkydC6OXafym6NCi1_B5iq5HmNUeM9ya224ePKJjPjQbEOjGRuoThcV4mcgLkJzLdLcMkDaWKaySXsCvsgt1ZbYMhSjw2OjeMne4pZOi1rEE-jQqh9fyFSUDCc78d8jml6poBPQaNieEYGyFRLcYERyROFv2VAi_W4vR-T5NEBg_P_eyN2IlRUjn83PMBQOBj7CL28W5CURV_iwGmtovA3q9iUq2669Mt3OZ2PsMtD765-d3NRmQPnOutpT6PKoBhQLtB981V6ut_l3T-pAwltguAxiMhk3z0j-40Suxt_WZW3h_MrcQf4MNqpko3-g3oQl50Iop2H9IiK0clKUzXqCSu2xvnI5cLEaoic_9T_o7llUO7OG2EeJE9emox',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...
