# %%
# Import dependencies
import json
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import time
import timeit
from datetime import datetime
from citipy import citipy

# %%
import requests
from config import weather_api_key

# %%
# Create set of 2000 random long and lats
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_descrip,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alindao
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | bereznyky
# Processing Record 4 of Set 1 | ambulu
# Processing Record 5 of Set 1 | namatanai
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | komsomolskiy
# Processing Record 9 of Set 1 | romitan
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | villefontaine
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | eureka
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | gejiu
# Processing Record 17 of Set 1 | quang ngai
# Processing Record 18 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | anadyr
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | trujillo
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | naze
# Processing Record 25 of Set 1 | srednekolymsk
# Processing Record 26 of Set 1 | libreville
# Processing Record 27 of Set 1 | moissala
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | vestmannaeyjar
# Processing Record 39 of Set 1 | ahipara
# Processing Record 40 of Set 1 | half moon bay
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | ballina
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | puerto ayacucho
# Processing Record 45 of Set 1 | los llanos de aridane
# Processing Record 46 of Set 1 | ahuimanu
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | cuitlahuac
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | tiruchchendur
# Processing Record 4 of Set 2 | alyangula
# Processing Record 5 of Set 2 | bandarbeyla
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | caucaia
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | kindu
# Processing Record 13 of Set 2 | masterton
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | vostok
# Processing Record 16 of Set 2 | petrove
# Processing Record 17 of Set 2 | coahuayana
# Processing Record 18 of Set 2 | hami
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | xiaoshi
# Processing Record 21 of Set 2 | bilibino
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | moron
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | santa maria
# Processing Record 31 of Set 2 | brae
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 2 | salobrena
# Processing Record 36 of Set 2 | gizo
# Processing Record 37 of Set 2 | kahului
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | thompson
# Processing Record 40 of Set 2 | wanning
# Processing Record 41 of Set 2 | jennings
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | amarante do maranhao
# Processing Record 44 of Set 2 | bartica
# Processing Record 45 of Set 2 | ayagoz
# Processing Record 46 of Set 2 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | sola
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | bairiki
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | itarema
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | rhyl
# Processing Record 6 of Set 3 | holme
# Processing Record 7 of Set 3 | puerto leguizamo
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | herouville-saint-clair
# Processing Record 12 of Set 3 | praia da vitoria
# Processing Record 13 of Set 3 | bad freienwalde
# Processing Record 14 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 3 | manokwari
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | kodiak
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | khani
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | saravan
# Processing Record 27 of Set 3 | jhawarian
# Processing Record 28 of Set 3 | manado
# Processing Record 29 of Set 3 | arman
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | simbahan
# Processing Record 32 of Set 3 | cherskiy
# Processing Record 33 of Set 3 | kloulklubed
# Processing Record 34 of Set 3 | coihaique
# Processing Record 35 of Set 3 | te anau
# Processing Record 36 of Set 3 | matveyevka
# Processing Record 37 of Set 3 | saint anthony
# Processing Record 38 of Set 3 | hamilton
# Processing Record 39 of Set 3 | ilulissat
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | sakakah
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | korla
# Processing Record 45 of Set 3 | nabire
# Processing Record 46 of Set 3 | nemuro
# Processing Record 47 of Set 3 | hithadhoo
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | tubuala
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | alice springs
# Processing Record 3 of Set 4 | kapra
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | hermitage
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | jibuti
# Processing Record 8 of Set 4 | kumluca
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | karymskoye
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | bitung
# Processing Record 13 of Set 4 | spencer
# Processing Record 14 of Set 4 | avera
# Processing Record 15 of Set 4 | treinta y tres
# Processing Record 16 of Set 4 | sovetskaya
# Processing Record 17 of Set 4 | howell
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | kosai
# Processing Record 20 of Set 4 | acapulco
# Processing Record 21 of Set 4 | aquidauana
# Processing Record 22 of Set 4 | roald
# Processing Record 23 of Set 4 | berezovyy
# Processing Record 24 of Set 4 | ocos
# Processing Record 25 of Set 4 | catio
# Processing Record 26 of Set 4 | yanam
# Processing Record 27 of Set 4 | taksimo
# Processing Record 28 of Set 4 | turukhansk
# Processing Record 29 of Set 4 | plastun
# Processing Record 30 of Set 4 | lampa
# Processing Record 31 of Set 4 | lavrentiya
# Processing Record 32 of Set 4 | ketchikan
# Processing Record 33 of Set 4 | yining
# Processing Record 34 of Set 4 | sungaipenuh
# Processing Record 35 of Set 4 | pisco
# Processing Record 36 of Set 4 | havelock
# Processing Record 37 of Set 4 | aquiraz
# Processing Record 38 of Set 4 | dali
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | taos
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | namibe
# Processing Record 44 of Set 4 | gremyachinsk
# Processing Record 45 of Set 4 | zeya
# Processing Record 46 of Set 4 | shirokiy
# Processing Record 47 of Set 4 | canaries
# Processing Record 48 of Set 4 | naryan-mar
# Processing Record 49 of Set 4 | xinzhi
# Processing Record 50 of Set 4 | nome
# Processing Record 1 of Set 5 | loa janan
# Processing Record 2 of Set 5 | chokurdakh
# Processing Record 3 of Set 5 | urucara
# Processing Record 4 of Set 5 | ulaangom
# Processing Record 5 of Set 5 | fort-shevchenko
# Processing Record 6 of Set 5 | assiniboia
# Processing Record 7 of Set 5 | tromso
# Processing Record 8 of Set 5 | elista
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | quatre cocos
# Processing Record 11 of Set 5 | mombasa
# Processing Record 12 of Set 5 | ancud
# Processing Record 13 of Set 5 | haaren
# Processing Record 14 of Set 5 | saint-philippe
# Processing Record 15 of Set 5 | celestun
# Processing Record 16 of Set 5 | itoman
# Processing Record 17 of Set 5 | rocha
# Processing Record 18 of Set 5 | sumbe
# Processing Record 19 of Set 5 | madimba
# Processing Record 20 of Set 5 | hay river
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | laguna
# Processing Record 24 of Set 5 | mandera
# Processing Record 25 of Set 5 | saint-joseph
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | beringovskiy
# Processing Record 28 of Set 5 | mirnyy
# Processing Record 29 of Set 5 | berestechko
# Processing Record 30 of Set 5 | plettenberg bay
# Processing Record 31 of Set 5 | trincomalee
# Processing Record 32 of Set 5 | biloela
# Processing Record 33 of Set 5 | birjand
# Processing Record 34 of Set 5 | catamarca
# Processing Record 35 of Set 5 | nykobing
# City not found. Skipping...
# Processing Record 36 of Set 5 | nouakchott
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | lumphat
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | carnarvon
# Processing Record 43 of Set 5 | oinoussai
# City not found. Skipping...
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | masaki
# Processing Record 46 of Set 5 | ongole
# Processing Record 47 of Set 5 | tautira
# Processing Record 48 of Set 5 | dudinka
# Processing Record 49 of Set 5 | najran
# Processing Record 50 of Set 5 | santa isabel do para
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | kirkwall
# Processing Record 3 of Set 6 | puerto escondido
# Processing Record 4 of Set 6 | shingu
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 6 | zhangye
# Processing Record 8 of Set 6 | ekibastuz
# Processing Record 9 of Set 6 | solntsevo
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | manggar
# Processing Record 12 of Set 6 | yar-sale
# Processing Record 13 of Set 6 | mecca
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 6 | bathsheba
# Processing Record 17 of Set 6 | nikolskoye
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | mormugao
# Processing Record 23 of Set 6 | ialibu
# Processing Record 24 of Set 6 | mocuba
# Processing Record 25 of Set 6 | tinaquillo
# Processing Record 26 of Set 6 | filotion
# Processing Record 27 of Set 6 | shar
# Processing Record 28 of Set 6 | alakurtti
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | denpasar
# Processing Record 31 of Set 6 | poddorye
# Processing Record 32 of Set 6 | isangel
# Processing Record 33 of Set 6 | umea
# Processing Record 34 of Set 6 | opuwo
# Processing Record 35 of Set 6 | boralday
# Processing Record 36 of Set 6 | muros
# Processing Record 37 of Set 6 | morlaix
# Processing Record 38 of Set 6 | kiunga
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | tocopilla
# Processing Record 41 of Set 6 | baykit
# Processing Record 42 of Set 6 | termiz
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | port augusta
# Processing Record 45 of Set 6 | mabaruma
# Processing Record 46 of Set 6 | paamiut
# Processing Record 47 of Set 6 | wenatchee
# Processing Record 48 of Set 6 | la romana
# Processing Record 49 of Set 6 | cidreira
# Processing Record 50 of Set 6 | agaro
# Processing Record 1 of Set 7 | annau
# Processing Record 2 of Set 7 | aksarka
# Processing Record 3 of Set 7 | atar
# Processing Record 4 of Set 7 | fukue
# Processing Record 5 of Set 7 | lakes entrance
# Processing Record 6 of Set 7 | egvekinot
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | mpanda
# Processing Record 9 of Set 7 | woodstock
# Processing Record 10 of Set 7 | thinadhoo
# Processing Record 11 of Set 7 | panixtlahuaca
# City not found. Skipping...
# Processing Record 12 of Set 7 | zemetchino
# Processing Record 13 of Set 7 | tukrah
# Processing Record 14 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 7 | krasnoarmeysk
# Processing Record 16 of Set 7 | bandrele
# Processing Record 17 of Set 7 | bad sachsa
# Processing Record 18 of Set 7 | kodoli
# Processing Record 19 of Set 7 | maldonado
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | port-gentil
# Processing Record 22 of Set 7 | nantucket
# Processing Record 23 of Set 7 | ambilobe
# Processing Record 24 of Set 7 | rock sound
# Processing Record 25 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 7 | codrington
# Processing Record 27 of Set 7 | shunyi
# Processing Record 28 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 7 | darhan
# Processing Record 30 of Set 7 | maceio
# Processing Record 31 of Set 7 | saldanha
# Processing Record 32 of Set 7 | dharchula
# Processing Record 33 of Set 7 | evensk
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | ambon
# Processing Record 36 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 7 | qasigiannguit
# Processing Record 38 of Set 7 | teno
# Processing Record 39 of Set 7 | chimore
# Processing Record 40 of Set 7 | jacksonville
# Processing Record 41 of Set 7 | aripuana
# Processing Record 42 of Set 7 | totolapan
# Processing Record 43 of Set 7 | la sarre
# Processing Record 44 of Set 7 | flinders
# Processing Record 45 of Set 7 | mayo
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | tazovskiy
# Processing Record 48 of Set 7 | curumani
# Processing Record 49 of Set 7 | estelle
# Processing Record 50 of Set 7 | axim
# Processing Record 1 of Set 8 | kruisfontein
# Processing Record 2 of Set 8 | zhigansk
# Processing Record 3 of Set 8 | erzin
# Processing Record 4 of Set 8 | bayan
# Processing Record 5 of Set 8 | broken hill
# Processing Record 6 of Set 8 | aklavik
# Processing Record 7 of Set 8 | bonthe
# Processing Record 8 of Set 8 | fairbanks
# Processing Record 9 of Set 8 | daru
# Processing Record 10 of Set 8 | belem de sao francisco
# Processing Record 11 of Set 8 | havre-saint-pierre
# Processing Record 12 of Set 8 | perth
# Processing Record 13 of Set 8 | svetlogorsk
# Processing Record 14 of Set 8 | leningradskiy
# Processing Record 15 of Set 8 | oxbow
# Processing Record 16 of Set 8 | deputatskiy
# Processing Record 17 of Set 8 | santa cruz
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | labuan
# Processing Record 20 of Set 8 | snyder
# Processing Record 21 of Set 8 | katsuura
# Processing Record 22 of Set 8 | bima
# Processing Record 23 of Set 8 | sorland
# Processing Record 24 of Set 8 | san policarpo
# Processing Record 25 of Set 8 | khryashchevka
# Processing Record 26 of Set 8 | chase
# Processing Record 27 of Set 8 | marawi
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | waipawa
# Processing Record 30 of Set 8 | narathiwat
# Processing Record 31 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 32 of Set 8 | imbituba
# Processing Record 33 of Set 8 | port hardy
# Processing Record 34 of Set 8 | turinskaya sloboda
# Processing Record 35 of Set 8 | venosa
# Processing Record 36 of Set 8 | henties bay
# Processing Record 37 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 8 | ponta do sol
# Processing Record 39 of Set 8 | chapleau
# Processing Record 40 of Set 8 | kikwit
# Processing Record 41 of Set 8 | dalby
# Processing Record 42 of Set 8 | srandakan
# Processing Record 43 of Set 8 | antri
# Processing Record 44 of Set 8 | brahmapuri
# City not found. Skipping...
# Processing Record 45 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 46 of Set 8 | psikhikon
# Processing Record 47 of Set 8 | bambous virieux
# Processing Record 48 of Set 8 | duldurga
# Processing Record 49 of Set 8 | chapais
# Processing Record 50 of Set 8 | dunedin
# Processing Record 1 of Set 9 | udupi
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 4 of Set 9 | zyryanka
# Processing Record 5 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 9 | san jeronimo
# Processing Record 7 of Set 9 | walla walla
# Processing Record 8 of Set 9 | lorengau
# Processing Record 9 of Set 9 | walvis bay
# Processing Record 10 of Set 9 | moncton
# Processing Record 11 of Set 9 | itaituba
# Processing Record 12 of Set 9 | mayumba
# Processing Record 13 of Set 9 | fonte boa
# Processing Record 14 of Set 9 | camacha
# Processing Record 15 of Set 9 | luganville
# Processing Record 16 of Set 9 | acarau
# Processing Record 17 of Set 9 | villazon
# Processing Record 18 of Set 9 | marzuq
# Processing Record 19 of Set 9 | kizilskoye
# Processing Record 20 of Set 9 | merano
# Processing Record 21 of Set 9 | banda aceh
# Processing Record 22 of Set 9 | great falls
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | kinablangan
# Processing Record 25 of Set 9 | norman wells
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | margate
# Processing Record 28 of Set 9 | masallatah
# Processing Record 29 of Set 9 | longjiang
# Processing Record 30 of Set 9 | kirillov
# Processing Record 31 of Set 9 | cienfuegos
# Processing Record 32 of Set 9 | bolobo
# Processing Record 33 of Set 9 | kerman
# Processing Record 34 of Set 9 | chicama
# Processing Record 35 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 9 | suntar
# Processing Record 37 of Set 9 | port moresby
# Processing Record 38 of Set 9 | olafsvik
# Processing Record 39 of Set 9 | bolotnoye
# Processing Record 40 of Set 9 | hohhot
# Processing Record 41 of Set 9 | hong gai
# Processing Record 42 of Set 9 | annamalainagar
# Processing Record 43 of Set 9 | gidole
# Processing Record 44 of Set 9 | vanimo
# Processing Record 45 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | norwich
# Processing Record 47 of Set 9 | terrak
# Processing Record 48 of Set 9 | mezen
# Processing Record 49 of Set 9 | otradnoye
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | asfi
# Processing Record 2 of Set 10 | mount gambier
# Processing Record 3 of Set 10 | kalmunai
# Processing Record 4 of Set 10 | kieta
# Processing Record 5 of Set 10 | sao filipe
# Processing Record 6 of Set 10 | ciudad bolivar
# Processing Record 7 of Set 10 | milkovo
# Processing Record 8 of Set 10 | killybegs
# Processing Record 9 of Set 10 | tranas
# Processing Record 10 of Set 10 | saint-pierre
# Processing Record 11 of Set 10 | tumaco
# Processing Record 12 of Set 10 | victoria
# Processing Record 13 of Set 10 | batagay-alyta
# Processing Record 14 of Set 10 | mackenzie
# Processing Record 15 of Set 10 | sovetskiy
# Processing Record 16 of Set 10 | mahebourg
# Processing Record 17 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 10 | beitbridge
# Processing Record 19 of Set 10 | cayenne
# Processing Record 20 of Set 10 | magan
# Processing Record 21 of Set 10 | kashirskoye
# Processing Record 22 of Set 10 | aljezur
# Processing Record 23 of Set 10 | naters
# Processing Record 24 of Set 10 | mashhad
# Processing Record 25 of Set 10 | jand
# Processing Record 26 of Set 10 | teguise
# Processing Record 27 of Set 10 | barra patuca
# Processing Record 28 of Set 10 | polunochnoye
# Processing Record 29 of Set 10 | buin
# Processing Record 30 of Set 10 | sobolevo
# Processing Record 31 of Set 10 | yulara
# Processing Record 32 of Set 10 | launceston
# Processing Record 33 of Set 10 | steinbach
# Processing Record 34 of Set 10 | khandyga
# Processing Record 35 of Set 10 | alofi
# Processing Record 36 of Set 10 | lukulu
# Processing Record 37 of Set 10 | lima
# Processing Record 38 of Set 10 | tefe
# Processing Record 39 of Set 10 | digha
# Processing Record 40 of Set 10 | airai
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | longyearbyen
# Processing Record 43 of Set 10 | elko
# Processing Record 44 of Set 10 | puno
# Processing Record 45 of Set 10 | delemont
# Processing Record 46 of Set 10 | seoul
# Processing Record 47 of Set 10 | arona
# Processing Record 48 of Set 10 | neiafu
# Processing Record 49 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 50 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 1 of Set 11 | male
# Processing Record 2 of Set 11 | fort collins
# Processing Record 3 of Set 11 | tallahassee
# Processing Record 4 of Set 11 | bhubaneswar
# Processing Record 5 of Set 11 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 6 of Set 11 | kralendijk
# Processing Record 7 of Set 11 | tilichiki
# Processing Record 8 of Set 11 | sur
# Processing Record 9 of Set 11 | calama
# Processing Record 10 of Set 11 | kysyl-syr
# Processing Record 11 of Set 11 | durres
# Processing Record 12 of Set 11 | oxford
# Processing Record 13 of Set 11 | merzifon
# Processing Record 14 of Set 11 | north platte
# Processing Record 15 of Set 11 | oprisor
# Processing Record 16 of Set 11 | portobelo
# Processing Record 17 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 18 of Set 11 | tabuk
# Processing Record 19 of Set 11 | samut sakhon
# Processing Record 20 of Set 11 | xushan
# Processing Record 21 of Set 11 | turan
# Processing Record 22 of Set 11 | pirapora
# Processing Record 23 of Set 11 | seydi
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | urubicha
# Processing Record 26 of Set 11 | atambua
# Processing Record 27 of Set 11 | benghazi
# Processing Record 28 of Set 11 | abu samrah
# Processing Record 29 of Set 11 | pires do rio
# Processing Record 30 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 11 | dauriya
# Processing Record 32 of Set 11 | manaus
# Processing Record 33 of Set 11 | grand gaube
# Processing Record 34 of Set 11 | baijiantan
# Processing Record 35 of Set 11 | cape canaveral
# Processing Record 36 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 38 of Set 11 | biak
# Processing Record 39 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 11 | merauke
# Processing Record 41 of Set 11 | newport
# Processing Record 42 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 11 | lensk
# Processing Record 44 of Set 11 | pemangkat
# Processing Record 45 of Set 11 | manaure
# Processing Record 46 of Set 11 | jiexiu
# Processing Record 47 of Set 11 | north bend
# Processing Record 48 of Set 11 | peace river
# Processing Record 49 of Set 11 | barcelos
# Processing Record 50 of Set 11 | port macquarie
# Processing Record 1 of Set 12 | karratha
# Processing Record 2 of Set 12 | batatais
# Processing Record 3 of Set 12 | burnie
# Processing Record 4 of Set 12 | nanortalik
# Processing Record 5 of Set 12 | bolshoye pikino
# City not found. Skipping...
# Processing Record 6 of Set 12 | haikou
# Processing Record 7 of Set 12 | karaton
# Processing Record 8 of Set 12 | guanica
# Processing Record 9 of Set 12 | porto novo
# Processing Record 10 of Set 12 | slyudyanka
# Processing Record 11 of Set 12 | moussoro
# Processing Record 12 of Set 12 | namanyere
# Processing Record 13 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 12 | balatan
# Processing Record 15 of Set 12 | polewali
# Processing Record 16 of Set 12 | solnechnyy
# Processing Record 17 of Set 12 | bethel
# Processing Record 18 of Set 12 | rurrenabaque
# Processing Record 19 of Set 12 | lagoa santa
# Processing Record 20 of Set 12 | prince rupert
# Processing Record 21 of Set 12 | dakar
# Processing Record 22 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 12 | san patricio
# Processing Record 24 of Set 12 | mayahi
# Processing Record 25 of Set 12 | palmares do sul
# Processing Record 26 of Set 12 | berlevag
# Processing Record 27 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 12 | west helena
# Processing Record 29 of Set 12 | ankang
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | belmonte
# Processing Record 32 of Set 12 | tecoanapa
# Processing Record 33 of Set 12 | taybad
# Processing Record 34 of Set 12 | kathmandu
# Processing Record 35 of Set 12 | ebetsu
# Processing Record 36 of Set 12 | nantai
# Processing Record 37 of Set 12 | bokajan
# Processing Record 38 of Set 12 | stokmarknes
# Processing Record 39 of Set 12 | grindavik
# Processing Record 40 of Set 12 | hulyaypole
# Processing Record 41 of Set 12 | keti bandar
# Processing Record 42 of Set 12 | maputo
# Processing Record 43 of Set 12 | kirovskiy
# Processing Record 44 of Set 12 | wesselsbron
# Processing Record 45 of Set 12 | pozo colorado
# Processing Record 46 of Set 12 | kiama
# Processing Record 47 of Set 12 | puerto narino
# Processing Record 48 of Set 12 | krasnorechenskiy
# Processing Record 49 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 50 of Set 12 | vao
# Processing Record 1 of Set 13 | brenes
# Processing Record 2 of Set 13 | puerto carreno
# Processing Record 3 of Set 13 | mason city
# Processing Record 4 of Set 13 | burns lake
# Processing Record 5 of Set 13 | san ramon
# Processing Record 6 of Set 13 | kidal
# Processing Record 7 of Set 13 | poum
# Processing Record 8 of Set 13 | praia
# Processing Record 9 of Set 13 | matadi
# Processing Record 10 of Set 13 | anjar
# Processing Record 11 of Set 13 | atka
# City not found. Skipping...
# Processing Record 12 of Set 13 | marsh harbour
# Processing Record 13 of Set 13 | ambovombe
# Processing Record 14 of Set 13 | cadiz
# Processing Record 15 of Set 13 | sangar
# Processing Record 16 of Set 13 | cortes
# Processing Record 17 of Set 13 | aswan
# Processing Record 18 of Set 13 | bara
# Processing Record 19 of Set 13 | pasinler
# Processing Record 20 of Set 13 | fethiye
# Processing Record 21 of Set 13 | orbetello
# Processing Record 22 of Set 13 | lompoc
# Processing Record 23 of Set 13 | whitehorse
# Processing Record 24 of Set 13 | kapuskasing
# Processing Record 25 of Set 13 | sept-iles
# Processing Record 26 of Set 13 | saint-francois
# Processing Record 27 of Set 13 | victor harbor
# Processing Record 28 of Set 13 | beatrice
# Processing Record 29 of Set 13 | yueyang
# Processing Record 30 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 31 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 13 | taft
# Processing Record 33 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 13 | coquimbo
# Processing Record 35 of Set 13 | kadhan
# Processing Record 36 of Set 13 | betioky
# Processing Record 37 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 38 of Set 13 | asau
# Processing Record 39 of Set 13 | tigre
# Processing Record 40 of Set 13 | salinopolis
# Processing Record 41 of Set 13 | mehran
# Processing Record 42 of Set 13 | dongkan
# Processing Record 43 of Set 13 | adrar
# Processing Record 44 of Set 13 | bilma
# Processing Record 45 of Set 13 | staryy nadym
# Processing Record 46 of Set 13 | cap malheureux
# Processing Record 47 of Set 13 | arucas
# Processing Record 48 of Set 13 | klyuchevskiy
# Processing Record 49 of Set 13 | troitskoye
# Processing Record 50 of Set 13 | erenhot
# Processing Record 1 of Set 14 | ilovlya
# Processing Record 2 of Set 14 | uribia
# Processing Record 3 of Set 14 | piranshahr
# Processing Record 4 of Set 14 | olinda
# Processing Record 5 of Set 14 | kungurtug
# Processing Record 6 of Set 14 | xining
# Processing Record 7 of Set 14 | silver city
# Processing Record 8 of Set 14 | easton
# Processing Record 9 of Set 14 | homer
# Processing Record 10 of Set 14 | palmer
# Processing Record 11 of Set 14 | nortelandia
# Processing Record 12 of Set 14 | isetskoye
# Processing Record 13 of Set 14 | vuktyl
# Processing Record 14 of Set 14 | dickinson
# Processing Record 15 of Set 14 | george
# Processing Record 16 of Set 14 | kamenka
# Processing Record 17 of Set 14 | san pedro
# Processing Record 18 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 19 of Set 14 | buala
# Processing Record 20 of Set 14 | butembo
# Processing Record 21 of Set 14 | neuquen
# Processing Record 22 of Set 14 | buraydah
# Processing Record 23 of Set 14 | kitui
# Processing Record 24 of Set 14 | samana
# Processing Record 25 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 14 | maralal
# Processing Record 27 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 14 | pitimbu
# Processing Record 29 of Set 14 | taoudenni
# Processing Record 30 of Set 14 | govindgarh
# Processing Record 31 of Set 14 | smithers
# Processing Record 32 of Set 14 | faya
# Processing Record 33 of Set 14 | nettuno
# Processing Record 34 of Set 14 | okhotsk
# Processing Record 35 of Set 14 | moerai
# Processing Record 36 of Set 14 | jaisalmer
# Processing Record 37 of Set 14 | byron bay
# Processing Record 38 of Set 14 | wasilla
# Processing Record 39 of Set 14 | oneida
# Processing Record 40 of Set 14 | varhaug
# Processing Record 41 of Set 14 | tacuarembo
# Processing Record 42 of Set 14 | urengoy
# Processing Record 43 of Set 14 | sedona
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | talcahuano
# Processing Record 46 of Set 14 | canmore
# Processing Record 47 of Set 14 | tambura
# Processing Record 48 of Set 14 | nordhausen
# Processing Record 49 of Set 14 | bakchar
# Processing Record 50 of Set 14 | inirida
# Processing Record 1 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 15 | meulaboh
# Processing Record 3 of Set 15 | giporlos
# Processing Record 4 of Set 15 | wawa
# Processing Record 5 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 15 | kardamaina
# Processing Record 7 of Set 15 | northam
# Processing Record 8 of Set 15 | puerto rondon
# Processing Record 9 of Set 15 | white rock
# Processing Record 10 of Set 15 | tupik
# Processing Record 11 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 15 | izumo
# Processing Record 13 of Set 15 | shipunovo
# Processing Record 14 of Set 15 | haines junction
# Processing Record 15 of Set 15 | ouallam
# Processing Record 16 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 15 | racale
# Processing Record 18 of Set 15 | abashiri
# Processing Record 19 of Set 15 | pirovskoye
# Processing Record 20 of Set 15 | abha
# Processing Record 21 of Set 15 | arlit
# Processing Record 22 of Set 15 | okakarara
# Processing Record 23 of Set 15 | saint-georges
# Processing Record 24 of Set 15 | tashtyp
# Processing Record 25 of Set 15 | helena
# Processing Record 26 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 15 | kuah
# Processing Record 28 of Set 15 | aizpute
# Processing Record 29 of Set 15 | la palma
# Processing Record 30 of Set 15 | agadir
# Processing Record 31 of Set 15 | bokhan
# Processing Record 32 of Set 15 | denizli
# Processing Record 33 of Set 15 | oistins
# Processing Record 34 of Set 15 | qostanay
# Processing Record 35 of Set 15 | oksfjord
# Processing Record 36 of Set 15 | domoni
# Processing Record 37 of Set 15 | karakol
# Processing Record 38 of Set 15 | perieti
# Processing Record 39 of Set 15 | kurikka
# Processing Record 40 of Set 15 | songjianghe
# Processing Record 41 of Set 15 | jati
# Processing Record 42 of Set 15 | anloga
# Processing Record 43 of Set 15 | hambantota
# Processing Record 44 of Set 15 | laela
# Processing Record 45 of Set 15 | vanavara
# Processing Record 46 of Set 15 | zhezkazgan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Alindao   5.0267   21.2088     77.61        25          16
# 1      Hermanus -34.4187   19.2345     63.81        76           0
# 2     Bereznyky  48.5141   23.2198     28.15        95          84
# 3        Ambulu  -8.3450  113.6058     75.42        86         100
# 4     Namatanai  -3.6667  152.4333     81.93        78          93
# 5        Dikson  73.5069   80.5464      3.24        94         100
# 6        Dingle  10.9995  122.6711     74.55        90          34
# 7  Komsomolskiy  40.4272   71.7189     36.32        41         100
# 8       Romitan  39.9343   64.3814     39.15        65         100
# 9       Rikitea -23.1203 -134.9692     78.06        70         100
#
#    Wind Speed Weather Description Country                 Date
# 0        3.94          few clouds      CF  2022-01-28 21:34:27
# 1       11.45           clear sky      ZA  2022-01-28 21:29:59
# 2        4.94       broken clouds      UA  2022-01-28 21:34:28
# 3        2.30     overcast clouds      ID  2022-01-28 21:34:29
# 4        3.71     overcast clouds      PG  2022-01-28 21:34:30
# 5       18.63     overcast clouds      RU  2022-01-28 21:34:31
# 6        4.27    scattered clouds      PH  2022-01-28 21:34:31
# 7        4.61     overcast clouds      UZ  2022-01-28 21:30:48
# 8       13.80     overcast clouds      UZ  2022-01-28 21:34:32
# 9       15.64     overcast clouds      PF  2022-01-28 21:34:32

# %%
# Rearrangle columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.columns.values[8] = 'Current Description'
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Alindao      CF   5.0267   21.2088     77.61        25          16
# 1   Hermanus      ZA -34.4187   19.2345     63.81        76           0
# 2  Bereznyky      UA  48.5141   23.2198     28.15        95          84
# 3     Ambulu      ID  -8.3450  113.6058     75.42        86         100
# 4  Namatanai      PG  -3.6667  152.4333     81.93        78          93
#
#    Wind Speed Current Description
# 0        3.94          few clouds
# 1       11.45           clear sky
# 2        4.94       broken clouds
# 3        2.30     overcast clouds
# 4        3.71     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
